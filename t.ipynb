# %%
from pathlib import Path

p = Path("a/b.txt")
print(p.with_suffix("csv"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from pathlib import Path
#       3 p = Path("a/b.txt")
# ----> 4 print(p.with_suffix("csv"))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ds/lib/python3.13/pathlib/_abc.py:232, in PurePathBase.with_suffix(self, suffix)
#     230     raise ValueError(f"{self!r} has an empty name")
#     231 elif suffix and not (suffix.startswith('.') and len(suffix) > 1):
# --> 232     raise ValueError(f"Invalid suffix {suffix!r}")
#     233 else:
#     234     return self.with_name(stem + suffix)
#
# ValueError: Invalid suffix 'csv'
